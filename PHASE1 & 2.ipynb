# %% [markdown]
# # PHASE-1

# %% [markdown]
# # DATA COLLECTION

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import warnings 
warnings.filterwarnings('ignore')

# %% [markdown]
# I have collected data from google and wikipedia manually. I have made an excel sheet of the collected data and uploaded in this
#
# jupyter file along with that i have filled the missing values by myself in this sheet to complete it . I made this excel file
#
# by taking help from (Crime in India: An Inter-State Analysis)
#
#
#
# I have made columns namely,
#
# Area of each state
#
# Population of each state from years 1991,2001,2011
#
# literacy of each state from years 1991,2001,2011
#
# Total Crime from these years
#
# Crime rate from these years
#
# Different crimes namely murders, rape, kidnapping, property crime from these years
#
# And overall crime

# %% [markdown]
# # IMPORTING FILE

# %%
df=pd.read_excel(r'C:\Users\Admin\Desktop\CAPSTONE.xls')
df
# Out:
#                       STATE/UT  AREA(km^2)  POPULATION(1991)  \
# 0               Andhra Pradesh      162975          66508170
# 1            Arunachal Pradesh       83743            865900
# 2                        Assam       78438          22414320
# 3                        Bihar       94163          64531200
# 4                 Chhattisgarh      135192          17615600
# 5                          Goa        3702           1170115
# 6                      Gujarat      196024          41309580
# 7                      Haryana       44212          16464600
# 8             Himachal pradesh       55673           5170877
# 9                    Jharkhand       79716          21844550
# 10                   Karnataka      191791          44977200
# 11                      Kerala       38863          29098523
# 12              Madhya Pradesh      308252          48566800
# 13                  Maharastra      307713          78937190
# ...

# %%
df.columns
# Out:
# Index(['STATE/UT', 'AREA(km^2)', 'POPULATION(1991)', 'POPULATION(2001)',
#        'POPULATION(2011)', 'LITERACY RATE(1991)', 'LITERACY RATE(2001)',
#        'LITERACY RATE(2011)', 'TOTAL CRIME(1991)', 'CRIME RATE(1991)',
#        'TOTAL CRIME(2001)', 'CRIME RATE(2001)', 'TOTAL CRIME(2011)',
#        'CRIME RATE(2011)', 'MURDER(1991)', 'MURDER(2001)', 'MURDER(2011)',
#        'RAPE(1991)', 'RAPE(2001)', 'RAPE(2011)', 'KIDNAPPING(1991)',
#        'KIDNAPPING(2001)', 'KIDNAPPING(2011)', 'PROPERTY CRIME(1991)',
#        'PROPERTY CRIME(2001)', 'PROPERTY CRIME(2011)', 'OVERALL CRIME'],
#       dtype='object')

# %%
df.dtypes
# Out:
# STATE/UT                 object
# AREA(km^2)                int64
# POPULATION(1991)          int64
# POPULATION(2001)          int64
# POPULATION(2011)          int64
# LITERACY RATE(1991)     float64
# LITERACY RATE(2001)     float64
# LITERACY RATE(2011)     float64
# TOTAL CRIME(1991)         int64
# CRIME RATE(1991)        float64
# TOTAL CRIME(2001)         int64
# CRIME RATE(2001)        float64
# TOTAL CRIME(2011)         int64
# CRIME RATE(2011)        float64
# MURDER(1991)              int64
# MURDER(2001)              int64
# MURDER(2011)              int64
# RAPE(1991)                int64
# RAPE(2001)                int64
# RAPE(2011)                int64
# KIDNAPPING(1991)          int64
# KIDNAPPING(2001)          int64
# KIDNAPPING(2011)          int64
# PROPERTY CRIME(1991)      int64
# PROPERTY CRIME(2001)      int64
# PROPERTY CRIME(2011)      int64
# OVERALL CRIME             int64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 37 entries, 0 to 36
# Data columns (total 27 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   STATE/UT              37 non-null     object
#  1   AREA(km^2)            37 non-null     int64
#  2   POPULATION(1991)      37 non-null     int64
#  3   POPULATION(2001)      37 non-null     int64
#  4   POPULATION(2011)      37 non-null     int64
#  5   LITERACY RATE(1991)   37 non-null     float64
#  6   LITERACY RATE(2001)   37 non-null     float64
#  7   LITERACY RATE(2011)   37 non-null     float64
#  8   TOTAL CRIME(1991)     37 non-null     int64
#  9   CRIME RATE(1991)      37 non-null     float64
#  10  TOTAL CRIME(2001)     37 non-null     int64
#  11  CRIME RATE(2001)      37 non-null     float64
#  12  TOTAL CRIME(2011)     37 non-null     int64
#  13  CRIME RATE(2011)      37 non-null     float64
#  14  MURDER(1991)          37 non-null     int64
# ...

# %%
df.shape
# Out:
# (37, 27)

# %%
df.isnull().sum()
# Out:
# STATE/UT                0
# AREA(km^2)              0
# POPULATION(1991)        0
# POPULATION(2001)        0
# POPULATION(2011)        0
# LITERACY RATE(1991)     0
# LITERACY RATE(2001)     0
# LITERACY RATE(2011)     0
# TOTAL CRIME(1991)       0
# CRIME RATE(1991)        0
# TOTAL CRIME(2001)       0
# CRIME RATE(2001)        0
# TOTAL CRIME(2011)       0
# CRIME RATE(2011)        0
# MURDER(1991)            0
# MURDER(2001)            0
# MURDER(2011)            0
# RAPE(1991)              0
# RAPE(2001)              0
# RAPE(2011)              0
# KIDNAPPING(1991)        0
# KIDNAPPING(2001)        0
# KIDNAPPING(2011)        0
# PROPERTY CRIME(1991)    0
# PROPERTY CRIME(2001)    0
# PROPERTY CRIME(2011)    0
# OVERALL CRIME           0
# dtype: int64

# %% [markdown]
# # PHASE-2

# %%
df.describe().T
# Out:
#                       count          mean           std       min         25%  \
# AREA(km^2)             37.0  8.848859e+04  9.555293e+04     32.00    10491.00
# POPULATION(1991)       37.0  2.371462e+07  2.993395e+07  52820.00   865900.00
# POPULATION(2001)       37.0  2.862892e+07  3.666881e+07  61300.00  1098328.00
# POPULATION(2011)       37.0  3.272169e+07  4.280609e+07  64473.00  1383727.00
# LITERACY RATE(1991)    37.0  5.872838e+01  1.403584e+01     38.48       44.20
# LITERACY RATE(2001)    37.0  6.938622e+01  1.094224e+01     47.00       61.00
# LITERACY RATE(2011)    37.0  7.973784e+01  8.135386e+00     63.82       73.45
# TOTAL CRIME(1991)      37.0  6.343978e+04  5.688400e+04   9209.00    16081.00
# CRIME RATE(1991)       37.0  3.770270e+00  3.361040e+00      0.50        1.30
# TOTAL CRIME(2001)      37.0  6.583503e+04  5.087339e+04   8746.00    23748.00
# CRIME RATE(2001)       37.0  3.818919e+00  2.805336e+00      0.40        1.90
# ...

# %%
plt.figure(figsize=(25,10))
sns.heatmap(df.describe(),annot=True)
plt.show()

# %% [markdown]
# OBSERVATIONS:

# %% [markdown]
# The maximum and minimum value of area in km in the dataset is 3.422390e and 32
#
# The minimum value of population in the dataset in years 1991,2001,2011 is 52820,61300,64473 respectively, while the maximum
# value of population in the respective years are 1.320628e,1.660536e,1.998123e.
#
# The minimum and maximum value of literacy rate in 1991,2001,2011 in this dataset are 38.48,47,63.82  and  8.979000e,9.09000e,
# 9.40000e respectively.
#
# The minimum and maximum number of Total Crime in the years 1991,2001,2011 in this dataset are 9209,8746,9876 and 2.184310e,
# 1.817410e 2.170940e respectively.
#
# while the Crime Rate varies from minimum to maximum in the years 1991,2001,2011 are 0.50,0.40,0.50  and 1.300000e,1.030000e,
# 9.300000e respectively.
#
# Along with that the Overall  Crime varies from 6925 to 2.294070e

# %% [markdown]
# # 2.1 NOW ANALYSIS OF LITERACY RATE VS TOTAL CRIME

# %% [markdown]
# # As We know that we have to analyse the literacy rate and total crime for years 1991,2001,and 2011 respectively

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(1991)', y='TOTAL CRIME(1991)',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# OBSERVATIONS:

# %% [markdown]
# We can see from the graph that the litearcy rate is inversely proportional to one another. The information which
#
# we gathered from the graph shows that the states which have high literacy rate have less number of total crime.
#
# But we get some exceptional data also that some of the states which have marginal better litercy than the other
#
# state have high total number of crime cases.

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(2001)', y='TOTAL CRIME(2001)',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In year 2001 there is a vast change in the variation among literacy rate and total crime , generally we can see that
#
# the states which have low literacy have high total number of crime but, from this graph we can see that somne of the
#
# state which have much better literacy rate have much lager value of total number of crime. some of the states which
#
# have literacy value like 56.3,63.7,73.5,76.9 also have much larger value of total number of crime.

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(2011)', y='TOTAL CRIME(2011)',data=df, palette='coolwarm',ci=68)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 2011 ,we can see that there is a graduall increase in the litearcy rate in the states from last 10 years.
#
# Along with that the total number of crime cases are also increases among last years. The reason for increasing
#
# the crime cases are unemployment, poverty and many more. As we can see that the state having 70.63 litearcy rate
#
# have highest peak of number of crime followed by 67.89,67.02,66.11,63.82 and even 94.

# %% [markdown]
# # ANALYSIS OF TYPE OF CRIME VS EACH STATE VS LITERACY RATE

# %% [markdown]
# In our dataset we have muder cases,rape cases,kidnapping cases,and property cases in Type Of Crime criteria

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(1991)', y='MURDER(1991)',hue='STATE/UT',data=df,ci=68)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# As we ca observe that in 1991 the literacy rate of most of the states is not much high but along with that we can see
#
# that in 1991 the number of murder cases are highest in uttarpradesh followed by bihar and then haryana
#
# From this graph we can also judge that inspite of having high literacy rate some of the states have high number of murder cases

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(2001)', y='MURDER(2001)',hue='STATE/UT',data=df,ci=68)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 2001 we can see that literacy rate is high as compared to the 1991 year and there is also downfall in the number
#
# of murder cases in the murder prone areas. As we have just saw that in 1991 the murder cases in rajasthan are app.
#
# 9999 but now they have decreased to 7635 app. followd by bihar and other states too.

# %%
plt.figure(figsize=(20,6))
sns.barplot(x='LITERACY RATE(2011)', y='MURDER(2011)',hue='STATE/UT',data=df,ci=68)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 2011 we noticed that there is a remakable change in rajasthan,westbengal ,bihar but we can also see that
#
# some areas have high number of murder cases as compared to 2001. This may be due to increase in the literacy
#
# rate ,as we know that more the people literate, less will be the crime.

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'RAPE(1991)',x= 'LITERACY RATE(1991)',hue='STATE/UT', data=df)
plt.xlabel('LITERACY RATE(1991)', fontsize = 14)
plt.ylabel('RAPE(1991)', fontsize = 14)
# Out:
# Text(0, 0.5, 'RAPE(1991)')

# %% [markdown]
# OBSERVATION:

# %% [markdown]
#  As we have already discussed that in this decade people are not much educated thats can be the reason of large
#
#     number of crimes in this era. As we can see that most of the rape cases can be seen in madhyapradesh followed
#
#     by uttarpradesh than rajasthan.

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'RAPE(2001)',x= 'LITERACY RATE(2001)',hue='STATE/UT', data=df)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 2001 we can see that there is very slight reduction in  the number of rape cases ,but  Rajasthan and Uttarpredsh
#
# have highest number of rape cases followed by madhyapradesh and maharastra .We can also see that literacy rate of these
#
# states is much higher than those states which have less crime cases.

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'RAPE(2011)',x= 'LITERACY RATE(2011)',hue='STATE/UT', data=df)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 2011 we can observe a vast increase in the rape cases amongst all states but Madhyapradesh,rajasthan, uttarpradesh
#
# and uttarakhand have highest values

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'KIDNAPPING(1991)',x= 'LITERACY RATE(1991)',hue='STATE/UT', data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'KIDNAPPING(2001)',x= 'LITERACY RATE(2001)',hue='STATE/UT', data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'KIDNAPPING(2011)',x= 'LITERACY RATE(2011)',hue='STATE/UT', data=df)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 1991 , the kidnapping cases are higher in Bihar, Gujrat, UttarPredesh, WestBengal, Karnataka and Rajasthan
# inspite of having high literacy rate of these areas.
#
# In 2001, we can notice there is a slight decrease in the kidnapping cases in thesa areas but anal some of the states
# have increas there numbers
#
# In 2011,we can observe that there is much hike in the number of kidnappind cases in all the states,
# through the given data it is clear that there is always incease in the crime cases in 2011

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'PROPERTY CRIME(1991)',x= 'LITERACY RATE(1991)',hue='STATE/UT', data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'PROPERTY CRIME(2001)',x= 'LITERACY RATE(2001)',hue='STATE/UT', data=df)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.barplot(y= 'PROPERTY CRIME(2011)',x= 'LITERACY RATE(2011)',hue='STATE/UT', data=df)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# If we compare the property crime cases in last years as in 1991,2001,and 2011, we can see that with the growing
#
# years the number of crime cases also increase witha  termendous amount. Through data we came to know that
#
# in Arunanchal Pradesh, Bihar, Kranataka, Gujrat, and Delhi have large number of cases in 40863(Delhi) with the
#
# growing years the literact rate of the states increase but crime cases also increase.

# %% [markdown]
# # ANALYSIS OF YEAR-ON-YEAR TOTAL CRIME RATE

# %%
plt.figure(figsize=(20,7))
sns.lineplot(y= 'CRIME RATE(1991)',x= 'STATE/UT', data=df)
plt.xlabel('STATE/UT', fontsize = 14)
plt.ylabel('CRIME RATE', fontsize = 14)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['CRIME RATE(2001)'],y=df['STATE/UT'], data=df)
plt.title('Bar Plot')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(y= 'CRIME RATE(2011)',x= 'STATE/UT', data=df)
plt.xlabel('STATE/UT', fontsize = 14)
plt.ylabel('CRIME RATE', fontsize = 14)
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# OBSERVATION:

# %% [markdown]
# In 1991, we can see that Kerala, MadhyaPradesh, Maharastra has high crime rate then followed by Tripura
# UttarPradesh Uttarakhand  and the rajasthan and sikkim
#
# In 2001, AndraPradesh, Bihar, Rajasthan MadhyaPradesh Tripura Uttarpradesh have peaks of crime rate followed
# b Uttarakhand Telangana
#
# In 2011, we can observe that,Kerala, Karnataka, Uttarpradesh rajasthan have hig crime rate

# %% [markdown]
# # ANALYSIS OF AREA VS OVERALL CRIME

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['OVERALL CRIME'],y=df['AREA(km^2)'], data=df)
plt.title('Bar Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # ANALYSIS OF POPULATION VS OVERALL CRIME

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['OVERALL CRIME'],y=df['POPULATION(1991)'], data=df)
plt.title('Bar Plot')
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(20,7))
sns.lineplot(y= 'POPULATION(2001)',x= 'OVERALL CRIME', data=df)
plt.xlabel('OVERALL CRIME', fontsize = 14)
plt.ylabel('POPULATION(2001)', fontsize = 14)
plt.xticks(rotation=90)
plt.show()

# %%
plt.figure(figsize=(15,6))
sns.barplot(x=df['OVERALL CRIME'],y=df['POPULATION(2011)'], data=df)
plt.title('Bar Plot')
plt.xticks(rotation=90)
plt.show()

# %% [markdown]
# # CRIME REPORT OF EACH STATE

# %% [markdown]
# The crime rate report of India in 2011 reveals a marginal increase of 0.56% in the overall crime rate compared to the previous
# decades.
#
# However, certain specific crimes have exhibited an increase in reported incidents. Cases of rape have risen by larger value,
# while,instances of kidnapping and abduction have witnessed a slight surge. Urban areas continue to have higher crime rates in
# comparison to rural regions. The report attributes the decline in the overall crime rate to factors like heightened police
# presence, improved law enforcement measures, and increased public awareness about crime prevention.
#
# Nevertheless, the report acknowledges persisting challenges, including the need for enhanced police training and increased
# resources to support law enforcement efforts. While some progress has been made in reducing crime, the report emphasizes
# the significance of public awareness and enhanced collaboration between law enforcement and the community.
#
# The most common crime in India is murder, followed by kidnapping and assault.
#
# The states with the highest crime rates in India are Uttar Pradesh, Kerala, Maharashtra, Delhi, and Bihar.
#
# The crime rate in urban areas is higher than the crime rate in rural areas.
#
# The report attributes the decrease in the overall crime rate to a number of factors, including increased police presence,
# improved law enforcement, and greater public awareness of crime.
#
# The report also notes that there are still some challenges that need to be addressed, such as the need for better training
# for police officers and the need for more resources to support law enforcement....
#
#
# States with the most Number of Crimes Rate
#
# 1.Uttar Pradesh: The per capita crime rate of UP is 7.4. According to the National Crime Records Bureau, this ratio means that
# Uttar Pradesh has the highest number of crimes, and thus, the state is unsafe to travel alone.
#
# 2.Arunachal Pradesh: The crime rate and other factors have made the state responsible for coming second in danger.
# Traveling alone after dark is banned in many areas of Arunachal Pradesh. The crime rate is around 5.8 and it is increasing
# with the increasing number of crimes.
#
# 3.Jharkhand: Jharkhand is another state which should not be missed from the point of view of danger. Little has been done
# for the safety of the people. Many criminal cases are not even registered in the police files.
#
# 4.Meghalaya: Meghalaya ranks fourth in terms of security and crime. Some areas in Meghalaya are said to be unsafe for travel
# and restricted for people. In recent reports, the state was declared with crimes rate of 5.1 and is considered one of the
# top dangerous states in India.
#
# 5.Delhi: Although Delhi ranks fifth, the state has a crime rate of 5 per capita as per the crime bureau. The sad fact is that
# despite the reign of political power in the state; Very little has been done in terms of its safety.
#
# 6.Assam: Ranks sixth in terms of crime rate in India. As compared to other states, Assam has registered a crime ratio of 4.4
# per capita in India. We are yet to go with 4 more top dangerous states in India.
#
# 7.Chhattisgarh: Crime has also increased to a great extent in Chhattisgarh. The state has a crime rate rating of 4 per capita
# and this is an alarming number enough to mention. This place is considered unsafe for many reasons, especially for women.
#
# 8.Haryana: Haryana has recorded a per capita crime rate of 3.8. The state is known for robbery, theft, bribery, murder, rape,
# and more. Thus, the political powers are trying to take stringent measures to control the crime rate. It is also called one
# of the 10 most dangerous states of India.
#
# 9.Odisha: Also shares 3.8 per capita crimes in India. The place is known for larceny, theft, and bribery. Various areas have
# been targeted for drugs and drunkenness. It has also spoiled the youth to a great extent in drug addiction.
#
# 10.Andhra Pradesh: Last but, not least is the crime rate in Andhra Pradesh. The state has increased to a 3.6 per capita ratio

# %% [markdown]
# # PHASE----4

# %% [markdown]
# # SENSITIVE AREA

# %%
df1=pd.read_excel(r'C:\Users\Admin\Desktop\SSS.xls')
df1
# Out:
#            STATE/UT       DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0    ANDHRA PRADESH       ADILABAD  2001     101                 60
# 1    ANDHRA PRADESH      ANANTAPUR  2001     151                125
# 2    ANDHRA PRADESH       CHITTOOR  2001     101                 57
# 3    ANDHRA PRADESH  EAST GODAVARI  2001      82                 67
# 4    ANDHRA PRADESH         GUNTUR  2001     182                 88
# ..              ...            ...   ...     ...                ...
# 592        DELHI UT          OUTER  2012      96                 60
# 593        DELHI UT          SOUTH  2012      39                 19
# 594        DELHI UT     SOUTH-EAST  2012      46                 69
# 595        DELHI UT     SOUTH-WEST  2012      47                 48
# 596        DELHI UT           WEST  2012      52                 37
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                           17    50               0
# ...

# %% [markdown]
# # MODERATE AREA

# %%
df2=pd.read_excel(r'C:\Users\Admin\Desktop\ERER.xls')
df2
# Out:
#            STATE/UT     DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0    ANDHRA PRADESH     CUDDAPAH  2001      80                 53
# 1    ANDHRA PRADESH        MEDAK  2001     101                 56
# 2    ANDHRA PRADESH    NIZAMABAD  2001     106                 49
# 3    ANDHRA PRADESH    PRAKASHAM  2001     102                 82
# 4    ANDHRA PRADESH   SRIKAKULAM  2001      38                 10
# ..              ...          ...   ...     ...                ...
# 922     WEST BENGAL  SILIGURI_PC  2012      32                  6
# 923        DELHI UT      CENTRAL  2012      35                 25
# 924        DELHI UT    NEW DELHI  2012       9                  6
# 925        DELHI UT        NORTH  2012      25                 17
# 926      PUDUCHERRY   PUDUCHERRY  2012      24                 21
#
#      CULPABLE HOMICIDE NOT AMOUNTING TO MURDER  RAPE  CUSTODIAL RAPE  \
# 0                                            1    20               0
# ...

# %% [markdown]
# # PEACEFUL AREA

# %%
df3=pd.read_excel(r'C:\Users\Admin\Desktop\FDF.xls')
df3
# Out:
#               STATE/UT           DISTRICT  YEAR  MURDER  ATTEMPT TO MURDER  \
# 0       ANDHRA PRADESH      GUNTAKAL RLY.  2001       3                  1
# 1       ANDHRA PRADESH  SECUNDERABAD RLY.  2001       6                  0
# 2       ANDHRA PRADESH    VIJAYAWADA RLY.  2001       2                  1
# 3    ARUNACHAL PRADESH          CHANGLANG  2001      11                  2
# 4    ARUNACHAL PRADESH      DIBANG VALLEY  2001       3                  5
# ..                 ...                ...   ...     ...                ...
# 626           DELHI UT        IGI AIRPORT  2012       1                  0
# 627           DELHI UT                STF  2012       0                  1
# 628        LAKSHADWEEP        LAKSHADWEEP  2012       0                  0
# 629        LAKSHADWEEP              TOTAL  2012       0                  0
# 630         PUDUCHERRY           KARAIKAL  2012       5                  6
#
# ...

# %% [markdown]
# # YEARLY CRIME RATE ANALYSIS FOR SENSITIVE AREA,MODERATE AREA PEACEFUL AREA

# %%
plt.figure(figsize=(5,5))
df1.groupby("YEAR")["TOTAL IPC CRIMES"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
plt.figure(figsize=(5,5))
df2.groupby("YEAR")["TOTAL IPC CRIMES"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %%
plt.figure(figsize=(5,5))
df3.groupby("YEAR")["TOTAL IPC CRIMES"].sum().plot.bar()
# Out:
# <AxesSubplot:xlabel='YEAR'>

# %% [markdown]
# # Percentage Distribution of each Crime based on Year in sensitive moderate and peaceful areas

# %%
df1.groupby("YEAR")["RAPE"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df2.groupby("YEAR")["RAPE"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df3.groupby("YEAR")["RAPE"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df1.groupby("YEAR")["KIDNAPPING & ABDUCTION"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df2.groupby("YEAR")["KIDNAPPING & ABDUCTION"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
df3.groupby("YEAR")["KIDNAPPING & ABDUCTION"].sum().plot.pie(autopct='%1.0f%%')
plt.tight_layout()

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,4,1)

df1.groupby("YEAR")["DOWRY DEATHS"].sum().plot(title="Dowry Deaths")
plt.subplot(2,4,1)
df1.groupby("YEAR")["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().plot(title="Assault on women with intent to outrage her modesty")
plt.subplot(2,4,2)
df1.groupby("YEAR")["INSULT TO MODESTY OF WOMEN"].sum().plot(title="Insult to modesty of Women")
plt.subplot(2,4,3)
df1.groupby("YEAR")["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().plot(title="Cruelty by Husband or his Relatives")
plt.subplot(2,4,4)
df1.groupby("YEAR")["IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"].sum().plot(title="Importation of Girls")
plt.subplot(2,4,5)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,4,1)

df2.groupby("YEAR")["DOWRY DEATHS"].sum().plot(title="Dowry Deaths")
plt.subplot(2,4,1)
df2.groupby("YEAR")["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().plot(title="Assault on women with intent to outrage her modesty")
plt.subplot(2,4,2)
df2.groupby("YEAR")["INSULT TO MODESTY OF WOMEN"].sum().plot(title="Insult to modesty of Women")
plt.subplot(2,4,3)
df2.groupby("YEAR")["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().plot(title="Cruelty by Husband or his Relatives")
plt.subplot(2,4,4)
df2.groupby("YEAR")["IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"].sum().plot(title="Importation of Girls")
plt.subplot(2,4,5)
# Out:
# <AxesSubplot:>

# %%
plt.figure(figsize=(20,12))
plt.subplot(2,4,1)

df3.groupby("YEAR")["DOWRY DEATHS"].sum().plot(title="Dowry Deaths")
plt.subplot(2,4,1)
df3.groupby("YEAR")["ASSAULT ON WOMEN WITH INTENT TO OUTRAGE HER MODESTY"].sum().plot(title="Assault on women with intent to outrage her modesty")
plt.subplot(2,4,2)
df3.groupby("YEAR")["INSULT TO MODESTY OF WOMEN"].sum().plot(title="Insult to modesty of Women")
plt.subplot(2,4,3)
df3.groupby("YEAR")["CRUELTY BY HUSBAND OR HIS RELATIVES"].sum().plot(title="Cruelty by Husband or his Relatives")
plt.subplot(2,4,4)
df3.groupby("YEAR")["IMPORTATION OF GIRLS FROM FOREIGN COUNTRIES"].sum().plot(title="Importation of Girls")
plt.subplot(2,4,5)
# Out:
# <AxesSubplot:>

# %% [markdown]
# #  1.WHAT IS IMPACTING MORE CRIME IN SENSITIVE AREAS

# %% [markdown]
# Some factors that are known to impact more crime in sensitive areas are:
#
# 1.Population density and degree of urbanization.
#
# 2.Variations in composition of the population, particularly youth concentration.
#
# 3.Stability of the population with respect to residents’ mobility, commuting patterns, and transient factors.
#
# 4.Modes of transportation and highway system.
#
# 5.Economic conditions, including median income, poverty level, and job availability.
#
# 6.Cultural factors and educational, recreational, and religious characteristics.
#
# 7.Family conditions with respect to divorce and family cohesiveness.
#
# 8.Effective strength of law enforcement agencies.
#
# 9.Administrative and investigative emphases of law enforcement.
#
# 10.Policies of other components of the criminal justice system (i.e., prosecutorial, judicial, correctional, and probational).
#
# 11.Citizens’ attitudes toward crime.
#
# 12.Crime reporting practices of the citizenry.

# %% [markdown]
# # 2. WHAT NEEDS TO BE DONE TO REDUCE CRIME

# %% [markdown]
# 1.Reducing crime is a complex issue that requires a multi-faceted approach. Here are some effective methods for reducing crime:
# Community-based policing:
# This approach involves the police working closely with the community to identify and solve problems related to crime.
#
# 2.Implement measures to improve witness protection and enhance the efficiency of the criminal justice system.
# Crime prevention is critical to maintain law and order in the country.
# Deterring criminals through deployment of more police is one of the major strategy practised
#
# 3.Education prevents crime by first, keeping teenagers and the youth busy as they engage with school work.
# Education is also able to instil a new thinking in the mindset of an individual.
# Individuals are able to analyse and correlate the impact of their current decisions-actions-and the future
#
# 4.Remember to close and lock all windows and doors even if you are only going out for a few minutes.
#
# 5.Most callers to your home will be genuine, however if you are in any doubt simply ask for their ID and check the caller out.

# %% [markdown]
# # 3. MOST SAFE AND UNSAFE DISTRICTS

# %% [markdown]
# # DISTRICTS WITH HIGHER NUMBER OF CRIMES

# %%
g= pd.DataFrame(df1.groupby(['DISTRICT'])['TOTAL IPC CRIMES'].sum().reset_index())

# %%
g
# Out:
#               DISTRICT  TOTAL IPC CRIMES
# 0    24 PARGANAS NORTH             25890
# 1    24 PARGANAS SOUTH             26921
# 2             ADILABAD             14897
# 3                 AGRA             20821
# 4     AHMEDABAD COMMR.             52311
# ..                 ...               ...
# 294     WARANGAL URBAN              3583
# 295             WARDHA              7582
# 296               WEST             20465
# 297      WEST GODAVARI             20763
# 298           YAVATMAL             15961
#
# [299 rows x 2 columns]

# %% [markdown]
# # DISTRICT WITH LOWER NUMBER OF CRIMES

# %%
f= pd.DataFrame(df3.groupby(['DISTRICT'])['TOTAL IPC CRIMES'].sum().reset_index())
f
# Out:
#             DISTRICT  TOTAL IPC CRIMES
# 0          AHWA-DANG               502
# 1             AIZAWL              1439
# 2             ALMORA               655
# 3     AMBEDKAR NAGAR               886
# 4            ANDAMAN              1303
# ..               ...               ...
# 274  W.RLY AHMEDABAD               344
# 275   W.RLY VADODARA               539
# 276             WEST               249
# 277            WOKHA               238
# 278        ZUNHEBOTO               170
#
# [279 rows x 2 columns]

# %% [markdown]
# # SO MOST SAFE DISTRICT TO STAY IS ZUNHEBOTO AND MOST UNSAFE DISTRICT TO STAY IS 24 PARAGNAS NORTH

# %% [markdown]
# # 4.4 CAPSTONE STORY

# %% [markdown]
# Crime and violence impact us psychologically (psychological factor), whether we are directly involved, a family member or friend
# is involved, our residence or community was impacted or exposure to it on media coverage. This is sometimes the case when a
# family member or friend is killed or hurt after directly or indirectly exposure to crime, it is natural for us to experience
# strong feelings and the effects may push some people state of mind beyond it optimal capability and may in turn leads to
# revenge or survival kind of crime(s).
#
# Also, Unemployment (economical factor) has a great deal of common sense appeal as one of the root cause of criminal behavior as
# unemployment is always viewed as a causal agent of economic deprivation may ultimately increases the probability of crime.
#
# The role of law enforcement officers (Security) is to protect citizenry against crimes. The research work did focus on the
# ratio of law enforcement to the crime rates. Does hiring more police /law enforcement officers curb the menace of crimes
#
# SOME OF THE FACTOR THAT AFFECT CRIME
#
# 1.Population: As widely known, population plays an important role is geographical location as population somethings
# (if not always) used to determine how wealthy, organized etc. that society are. It (Population) can also spells dome to the
# geographical location as it is something believe that the higher the population, the higher the crime rate and vice versa.
# I will not dispute this, but I will like to also shift our attention to some other factor we always overlooked like!
#
# 2.Crimes Rate : As the main culprit in our analysis, I collected dataset for crime rate for the country I was trying to dig
# deeper.
#
# 3.Law Enforcement: Total employed law enforcements at the time of the incident was also considered. As one article in newspaper
# say “The notion of pruning the police inevitably raises the specter of more crime, even if there is little evidence to support
# such fears. The relationship between the number of officers and lawful behavior is not clear-cut.
#
# 4.Unemployment: No society can escape this. Robert Frost once said, “The reason why worry kills more people than work is that
# more people worry that work”. Also, a school of thought said, “Idle hands are devils workshop”. You may want to turn to crime
# if you don’t work. Therefore, unemployment may be seen as a culprit.
#
# 5.Child Abuse and Neglect: I wanted to include this into the analysis, but the required datasets was not readily available at
# the time of this analysis. It would have been of great to see the effect(s) of child abuse and neglect in crime rate. Because,
